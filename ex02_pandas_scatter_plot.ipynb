# %%
# Exercise 2: Pandas Plot (Scatter Plot)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Create the DataFrame
df = pd.DataFrame({
    'name':['christopher','marion','maria','mia','clement','randy','remi'],
    'age':[70,30,22,19,45,33,20],
    'gender':['M','F','F','F','M','M','M'],
    'state':['california','dc','california','dc','california','new york','porto'],
    'num_children':[4,2,1,0,3,1,0],
    'num_pets':[5,1,0,2,2,2,3]
})

# %%
# Create scatter plot
ax = df.plot(x='age', y='num_children', kind='scatter', 
             title='Scatter plot: Number of children and age',
             figsize=(8, 6))

# Customize the plot
ax.set_xlabel('age')
ax.set_ylabel('num_children')
plt.tight_layout()
plt.show()

# %%
# More Examples

# %%
df.plot(kind="scatter", x="age", y="num_children", title="Age vs Number of Children")
plt.xlabel("Age")
plt.ylabel("Number of Children")
plt.show()

# %%
# Create the scatter plot
ax = df.plot(x='age', y='num_children', kind='scatter', 
             title='Age vs Number of Children', 
             figsize=(8, 6))
ax.set_xlabel('Age')
ax.set_ylabel('Number of Children')
plt.tight_layout()
plt.show()

# %%
# Create scatter plot
ax = df.plot(
    x='age',
    y='num_children',
    kind='scatter',
    title='Age vs Number of Children',
    figsize=(8, 6)
)
ax.set_xlabel('Age')
ax.set_ylabel('Number of Children')
plt.grid(True)
plt.show()
